# %%
import pandas as pd

# %%
breweries="data_world/breweries.csv"
brew_df=pd.read_csv(breweries)
brew_df.head(100)
# Out:
#      id                                               name  \
# 0     1                              (512) Brewing Company
# 1     2                        21st Amendment Brewery Cafe
# 2     3  3 Fonteinen Brouwerij Ambachtelijke Geuzestekerij
# 3     4                                       Aass Brewery
# 4     5                                    Abbaye de Leffe
# ..  ...                                                ...
# 95   98                                   Belhaven Brewery
# 96   99                                     Belize Brewing
# 97  100                                Bell's Brewery Inc.
# 98  101                                  Bellows Brew Crew
# 99  102                                 Bent River Brewing
#
#                           address1 address2           city           state  \
# 0                  407 Radam, F200      NaN         Austin           Texas
# 1                563 Second Street      NaN  San Francisco      California
# ...

# %%
columns=['id', 'name', 'address1', 'city', 'state', 'country', 'phone', 'website']
brew_reduced=brew_df.loc[:, columns]
brew_reduced.head(50)
# Out:
#     id                                               name  \
# 0    1                              (512) Brewing Company
# 1    2                        21st Amendment Brewery Cafe
# 2    3  3 Fonteinen Brouwerij Ambachtelijke Geuzestekerij
# 3    4                                       Aass Brewery
# 4    5                                    Abbaye de Leffe
# 5    6                                Abbaye de Maredsous
# 6    7                       Abbaye Notre Dame du St Remy
# 7    8                    Abbey Wright Brewing/Valley Inn
# 8    9                                   Aberdeen Brewing
# 9   10                              Abita Brewing Company
# 10  11                                       Adnams & Co.
# 11  12                                 Affligem Brouwerij
# 12  13                                    Agassiz Brewing
# 13  14                             Aksarben Brewing (BOP)
# 14  15                          Aktienbrauerei Kaufbeuren
# ...

# %%
brew_reduced.to_csv("cleaned_data_world/breweries_reduced_df.csv", index=False, header=True)
