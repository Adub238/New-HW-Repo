# %%
import pandas as pd

# %%
beer="data_world/beers-cleaned.csv"
beer_df=pd.read_csv(beer, encoding = "ISO-8859-1")
beer_df.head()
# Out:
# C:\Users\legweak2\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (10,18,19,20,21,23,25,33,34,36,38,46,48,50,58,60,62,70,72,74,82,84,86,94,96,98,106,108,110,118,120,122,130,132,134,144,146,154,156,158,166,168,170,178,180,182,190,192,194,202,204,206,214) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    id  brewery_id                    name  cat_id  style_id  abv   ibu  srm  \
# 0   1         812             Hocus Pocus      11       116  4.5  10.0  0.0
# 1   2         264       Grimbergen Blonde      -1        -1  6.7  10.0  0.0
# 2   3         779  Widdershins Barleywine      -1        -1  9.1  10.0  0.0
# 3   4         287                 Lucifer      -1        -1  8.5  10.0  0.0
# 4   5        1056                  Bitter      -1        -1    4  10.0  0.0
#
#    upc                                           descript  ... Unnamed: 205  \
# ...

# %%
columns=["id", 'name', 'brewery_id', 'cat_id', 'style_id', 'abv']
beer_reduced_df=beer_df.loc[:, columns]
beer_reduced_df.head(50)
# Out:
#     id                                     name  brewery_id  cat_id  style_id  \
# 0    1                              Hocus Pocus         812      11       116
# 1    2                        Grimbergen Blonde         264      -1        -1
# 2    3                   Widdershins Barleywine         779      -1        -1
# 3    4                                  Lucifer         287      -1        -1
# 4    5                                   Bitter        1056      -1        -1
# 5    6                            Winter Warmer        1385       1        13
# 6    7                 Winter Welcome 2007-2008        1099      -1        -1
# 7    8                            Oatmeal Stout        1099       3        42
# 8    9                          Espresso Porter         501      -1        -1
# 9   10                          Chocolate Stout         545       3        42
# 10  11          Hitachino Nest Real Ginger Brew         742      -1        -1
# ...

# %%
beer_reduced_df.to_csv("cleaned_data_world/beers_reduced_df.csv", index=False, header=True)
